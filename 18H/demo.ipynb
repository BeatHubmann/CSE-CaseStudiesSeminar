# %%
from tensorflow.keras import Sequential, optimizers
from tensorflow.keras.layers import Dense, Activation
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    return np.sin(np.sqrt(2) * x) * np.sin(2 * x)

# %%
num_points = 10000
x_min, x_max = - np.pi, 3 * np.pi
x = np.linspace(x_min, x_max, num_points)

# %%
model = Sequential()
model.add(Dense(256, input_dim=1, activation='sigmoid'))
model.add(Dense(128, activation='sigmoid'))
model.add(Dense(64, activation='sigmoid'))
model.add(Dense(1))
model.summary()
model.compile(loss='mse', 
              optimizer='nadam',
              metrics=['mae'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               512
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 41,729
# Trainable params: 41,729
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x, f(x),
                    batch_size=64, 
                    epochs=20, 
                    verbose=1)
# Out:
# Epoch 1/20
# 10000/10000 [==============================] - 1s 60us/step - loss: 0.1984 - mean_absolute_error: 0.3647
# Epoch 2/20
# 10000/10000 [==============================] - 0s 35us/step - loss: 0.1683 - mean_absolute_error: 0.3418
# Epoch 3/20
# 10000/10000 [==============================] - 0s 33us/step - loss: 0.1294 - mean_absolute_error: 0.3136
# Epoch 4/20
# 10000/10000 [==============================] - 0s 35us/step - loss: 0.1248 - mean_absolute_error: 0.3135
# Epoch 5/20
# 10000/10000 [==============================] - 0s 33us/step - loss: 0.1222 - mean_absolute_error: 0.3113
# Epoch 6/20
# 10000/10000 [==============================] - 0s 34us/step - loss: 0.1205 - mean_absolute_error: 0.3095
# Epoch 7/20
# 10000/10000 [==============================] - 0s 35us/step - loss: 0.1166 - mean_absolute_error: 0.3040
# Epoch 8/20
# 10000/10000 [==============================] - 0s 49us/step - loss: 0.1104 - mean_absolute_error: 0.2936
# Epoch 9/20
# 10000/10000 [==============================] - 0s 35us/step - loss: 0.1024 - mean_absolute_error: 0.2792
# Epoch 10/20
# 10000/10000 [==============================] - 0s 41us/step - loss: 0.0909 - mean_absolute_error: 0.2556
# Epoch 11/20
# 10000/10000 [==============================] - 0s 42us/step - loss: 0.0812 - mean_absolute_error: 0.2345
# Epoch 12/20
# 10000/10000 [==============================] - 0s 43us/step - loss: 0.0760 - mean_absolute_error: 0.2199
# Epoch 13/20
# 10000/10000 [==============================] - 0s 47us/step - loss: 0.0726 - mean_absolute_error: 0.2110
# Epoch 14/20
# 10000/10000 [==============================] - 0s 41us/step - loss: 0.0688 - mean_absolute_error: 0.2022
# Epoch 15/20
# 10000/10000 [==============================] - 0s 34us/step - loss: 0.0642 - mean_absolute_error: 0.1919
# Epoch 16/20
# 10000/10000 [==============================] - 0s 35us/step - loss: 0.0601 - mean_absolute_error: 0.1818
# Epoch 17/20
# 10000/10000 [==============================] - 0s 36us/step - loss: 0.0567 - mean_absolute_error: 0.1723
# Epoch 18/20
# 10000/10000 [==============================] - 0s 39us/step - loss: 0.0530 - mean_absolute_error: 0.1641
# Epoch 19/20
# 10000/10000 [==============================] - 0s 37us/step - loss: 0.0488 - mean_absolute_error: 0.1575
# Epoch 20/20
# 10000/10000 [==============================] - 0s 45us/step - loss: 0.0414 - mean_absolute_error: 0.1418

# %%
# %matplotlib notebook
plt.plot(history.history['mean_absolute_error'])
plt.title('training mean absolute error')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['training'], loc='upper left')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x_def = x[np.where((x[:] >= 0) & (x[:] <= 2 * np.pi))]
y_pred = model.predict(x_def).flatten() 
y_true = f(x_def)
error = y_true - y_pred

# %matplotlib notebook
fig, axs = plt.subplots(2, 1)
fig.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                wspace=0.2, hspace=0.5)

l1, l2 = axs[0].plot(x_def, y_true, x_def, y_pred)
axs[0].set_title('target vs interpolation')
axs[0].set_xlabel('$x$')
axs[0].set_ylabel('$y$')
axs[0].grid(True)
axs[0].legend((l1, l2), ('$y=f(x)$','$y=\hat{f}(x)$'))


l3 = axs[1].plot(x_def, error)            
axs[1].set_title('error')
axs[1].set_xlabel('$x$')
axs[1].set_ylabel('$f(x) - \hat{f}(x)$')    
axs[1].grid(True)

   
plt.show()
print('Maximum absolute error = {:.2}'.format(np.max(np.abs(error))))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Maximum absolute error = 0.51
